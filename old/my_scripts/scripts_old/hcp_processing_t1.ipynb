# %%
import glob
import numpy as np
import nibabel as nib
import matplotlib.pyplot as plt
import os

from dipy.core.gradients import gradient_table
from dipy.io import read_bvals_bvecs
from dipy.reconst.dti import TensorModel, fractional_anisotropy, mean_diffusivity

# %%
os.chdir('/space/hemera/1/users/cmaffei/hcp_processing/')
wd = '/space/hemera/1/users/cmaffei/hcp_processing/'

# %%
for sub in glob.glob(os.path.join(wd, 'mgh_*')):
    print(sub)
    #load data
    img = nib.load(os.path.join(sub, '1k/data_corr.nii.gz'))
    data = img.get_data()
    bvals, bvecs = read_bvals_bvecs(os.path.join(sub, '1k/bvals'), os.path.join(sub, '1k/bvecs'))
    gtab = gradient_table(bvals, bvecs)
    mask = nib.load(os.path.join(sub, 'mask_er.nii.gz')).get_data()
    #tensor estimation
    tenmodel = TensorModel(gtab)
    tenfit = tenmodel.fit(data, mask)
    FA = fractional_anisotropy(tenfit.evals)
    #save fa
    nib.save(nib.Nifti1Image(FA.astype('float32'), img.affine, img.header), os.path.join(sub, '1k/fa.nii.gz'))
# Out:
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1023
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1015
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1001
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1018
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1002
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1010
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1027
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1008
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1019
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1033
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1029
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1004
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1026
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1003
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1016
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1022
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1035
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1028
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1024
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1007
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1017
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1012
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1032
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1031
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1021
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1014
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1006
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1011
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1030
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1013
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1034
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1025
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1009
# /space/hemera/1/users/cmaffei/hcp_processing/mgh_1005

# %%
# %%script tcsh
# mrtrixenv
# foreach sub (mgh_????)
#     set wd = '/space/hemera/1/users/cmaffei/hcp_processing'
#     set input =  $sub/orig.mgz
#     set output = $sub/t1_bet.nii.gz
#     set mask =  $wd/1k/$sub/dlabel/anat/anat_brain_mask.nii.gz
#     mri_convert $input $sub/orig.nii.gz
#     rm $input
#     mrconvert $sub/orig.nii.gz -stride -1,2,3 $sub/t1.nii.gz -force
#     fslmaths $sub/t1.nii.gz -mas $mask $output
# end
# Out:
# mri_convert mgh_1001/orig.mgz mgh_1001/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1001/orig.mgz...
# mri_convert mgh_1002/orig.mgz mgh_1002/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1002/orig.mgz...
# mri_convert mgh_1003/orig.mgz mgh_1003/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1003/orig.mgz...
# mri_convert mgh_1004/orig.mgz mgh_1004/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1004/orig.mgz...
# mri_convert mgh_1005/orig.mgz mgh_1005/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1005/orig.mgz...
# mri_convert mgh_1006/orig.mgz mgh_1006/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1006/orig.mgz...
# mri_convert mgh_1007/orig.mgz mgh_1007/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1007/orig.mgz...
# mri_convert mgh_1008/orig.mgz mgh_1008/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1008/orig.mgz...
# mri_convert mgh_1009/orig.mgz mgh_1009/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1009/orig.mgz...
# mri_convert mgh_1010/orig.mgz mgh_1010/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1010/orig.mgz...
# mri_convert mgh_1011/orig.mgz mgh_1011/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1011/orig.mgz...
# mri_convert mgh_1012/orig.mgz mgh_1012/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1012/orig.mgz...
# mri_convert mgh_1013/orig.mgz mgh_1013/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1013/orig.mgz...
# mri_convert mgh_1014/orig.mgz mgh_1014/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1014/orig.mgz...
# mri_convert mgh_1015/orig.mgz mgh_1015/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1015/orig.mgz...
# mri_convert mgh_1016/orig.mgz mgh_1016/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1016/orig.mgz...
# mri_convert mgh_1017/orig.mgz mgh_1017/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1017/orig.mgz...
# mri_convert mgh_1018/orig.mgz mgh_1018/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1018/orig.mgz...
# mri_convert mgh_1019/orig.mgz mgh_1019/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1019/orig.mgz...
# mri_convert mgh_1020/orig.mgz mgh_1020/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1020/orig.mgz...
# mri_convert mgh_1021/orig.mgz mgh_1021/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1021/orig.mgz...
# mri_convert mgh_1022/orig.mgz mgh_1022/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1022/orig.mgz...
# mri_convert mgh_1023/orig.mgz mgh_1023/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1023/orig.mgz...
# mri_convert mgh_1024/orig.mgz mgh_1024/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1024/orig.mgz...
# mri_convert mgh_1025/orig.mgz mgh_1025/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1025/orig.mgz...
# mri_convert mgh_1026/orig.mgz mgh_1026/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1026/orig.mgz...
# mri_convert mgh_1027/orig.mgz mgh_1027/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1027/orig.mgz...
# mri_convert mgh_1028/orig.mgz mgh_1028/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1028/orig.mgz...
# mri_convert mgh_1029/orig.mgz mgh_1029/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1029/orig.mgz...
# mri_convert mgh_1030/orig.mgz mgh_1030/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1030/orig.mgz...
# mri_convert mgh_1031/orig.mgz mgh_1031/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1031/orig.mgz...
# mri_convert mgh_1032/orig.mgz mgh_1032/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1032/orig.mgz...
# mri_convert mgh_1033/orig.mgz mgh_1033/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1033/orig.mgz...
# mri_convert mgh_1034/orig.mgz mgh_1034/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1034/orig.mgz...
# mri_convert mgh_1035/orig.mgz mgh_1035/orig.nii.gz
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1035/orig.mgz...
# stdin: is not a tty
# mghRead(mgh_1001/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1001/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1001/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1001/orig.nii.gz" to "mgh_1001/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1001/t1.nii.gz"
# mghRead(mgh_1002/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1002/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1002/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1002/orig.nii.gz" to "mgh_1002/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1002/t1.nii.gz"
# mghRead(mgh_1003/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1003/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1003/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1003/orig.nii.gz" to "mgh_1003/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1003/t1.nii.gz"
# mghRead(mgh_1004/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1004/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1004/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1004/orig.nii.gz" to "mgh_1004/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1004/t1.nii.gz"
# mghRead(mgh_1005/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1005/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1005/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1005/orig.nii.gz" to "mgh_1005/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1005/t1.nii.gz"
# mghRead(mgh_1006/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1006/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1006/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1006/orig.nii.gz" to "mgh_1006/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1006/t1.nii.gz"
# mghRead(mgh_1007/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1007/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1007/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1007/orig.nii.gz" to "mgh_1007/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1007/t1.nii.gz"
# mghRead(mgh_1008/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1008/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1008/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1008/orig.nii.gz" to "mgh_1008/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1008/t1.nii.gz"
# mghRead(mgh_1009/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1009/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1009/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1009/orig.nii.gz" to "mgh_1009/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1009/t1.nii.gz"
# mghRead(mgh_1010/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1010/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1010/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1010/orig.nii.gz" to "mgh_1010/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1010/t1.nii.gz"
# mghRead(mgh_1011/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1011/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1011/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1011/orig.nii.gz" to "mgh_1011/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1011/t1.nii.gz"
# mghRead(mgh_1012/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1012/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1012/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1012/orig.nii.gz" to "mgh_1012/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1012/t1.nii.gz"
# mghRead(mgh_1013/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1013/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1013/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1013/orig.nii.gz" to "mgh_1013/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1013/t1.nii.gz"
# mghRead(mgh_1014/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1014/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1014/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1014/orig.nii.gz" to "mgh_1014/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1014/t1.nii.gz"
# mghRead(mgh_1015/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1015/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1015/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1015/orig.nii.gz" to "mgh_1015/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1015/t1.nii.gz"
# mghRead(mgh_1016/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1016/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1016/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1016/orig.nii.gz" to "mgh_1016/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1016/t1.nii.gz"
# mghRead(mgh_1017/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1017/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1017/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1017/orig.nii.gz" to "mgh_1017/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1017/t1.nii.gz"
# mghRead(mgh_1018/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1018/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1018/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1018/orig.nii.gz" to "mgh_1018/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1018/t1.nii.gz"
# mghRead(mgh_1019/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1019/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1019/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1019/orig.nii.gz" to "mgh_1019/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1019/t1.nii.gz"
# mghRead(mgh_1020/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1020/orig.mgz’: Not a directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [ERROR] Not a directory
# mrconvert: [ERROR] error opening image "mgh_1020/orig.nii.gz"
# Cannot open volume mgh_1020/t1 for reading!
# mghRead(mgh_1021/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1021/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1021/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1021/orig.nii.gz" to "mgh_1021/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1021/t1.nii.gz"
# mghRead(mgh_1022/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1022/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1022/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1022/orig.nii.gz" to "mgh_1022/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1022/t1.nii.gz"
# mghRead(mgh_1023/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1023/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1023/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1023/orig.nii.gz" to "mgh_1023/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1023/t1.nii.gz"
# mghRead(mgh_1024/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1024/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1024/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1024/orig.nii.gz" to "mgh_1024/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1024/t1.nii.gz"
# mghRead(mgh_1025/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1025/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1025/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1025/orig.nii.gz" to "mgh_1025/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1025/t1.nii.gz"
# mghRead(mgh_1026/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1026/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1026/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1026/orig.nii.gz" to "mgh_1026/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1026/t1.nii.gz"
# mghRead(mgh_1027/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1027/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1027/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1027/orig.nii.gz" to "mgh_1027/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1027/t1.nii.gz"
# mghRead(mgh_1028/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1028/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1028/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1028/orig.nii.gz" to "mgh_1028/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1028/t1.nii.gz"
# mghRead(mgh_1029/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1029/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1029/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1029/orig.nii.gz" to "mgh_1029/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1029/t1.nii.gz"
# mghRead(mgh_1030/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1030/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1030/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1030/orig.nii.gz" to "mgh_1030/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1030/t1.nii.gz"
# mghRead(mgh_1031/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1031/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1031/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1031/orig.nii.gz" to "mgh_1031/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1031/t1.nii.gz"
# Image Exception : #22 :: ERROR: Could not open image /space/hemera/1/users/cmaffei/hcp_processing/1k/mgh_1031/dlabel/anat/anat_brain_mask
# terminate called after throwing an instance of 'RBD_COMMON::BaseException'
# Abort (core dumped)
# mghRead(mgh_1032/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1032/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1032/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1032/orig.nii.gz" to "mgh_1032/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1032/t1.nii.gz"
# Image Exception : #22 :: ERROR: Could not open image /space/hemera/1/users/cmaffei/hcp_processing/1k/mgh_1032/dlabel/anat/anat_brain_mask
# terminate called after throwing an instance of 'RBD_COMMON::BaseException'
# Abort (core dumped)
# mghRead(mgh_1033/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1033/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1033/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1033/orig.nii.gz" to "mgh_1033/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1033/t1.nii.gz"
# Image Exception : #22 :: ERROR: Could not open image /space/hemera/1/users/cmaffei/hcp_processing/1k/mgh_1033/dlabel/anat/anat_brain_mask
# terminate called after throwing an instance of 'RBD_COMMON::BaseException'
# Abort (core dumped)
# mghRead(mgh_1034/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1034/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1034/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1034/orig.nii.gz" to "mgh_1034/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1034/t1.nii.gz"
# Image Exception : #22 :: ERROR: Could not open image /space/hemera/1/users/cmaffei/hcp_processing/1k/mgh_1034/dlabel/anat/anat_brain_mask
# terminate called after throwing an instance of 'RBD_COMMON::BaseException'
# Abort (core dumped)
# mghRead(mgh_1035/orig.mgz, -1): could not open file
# rm: cannot remove ‘mgh_1035/orig.mgz’: No such file or directory
# mrconvert: [WARNING] existing output files will be overwritten
# mrconvert: [100%] uncompressing image "mgh_1035/orig.nii.gz"
# mrconvert: [100%] copying from "mgh_1035/orig.nii.gz" to "mgh_1035/t1.nii.gz"
# mrconvert: [100%] compressing image "mgh_1035/t1.nii.gz"
# Image Exception : #22 :: ERROR: Could not open image /space/hemera/1/users/cmaffei/hcp_processing/1k/mgh_1035/dlabel/anat/anat_brain_mask
# terminate called after throwing an instance of 'RBD_COMMON::BaseException'
# Abort (core dumped)

# %%
# %%script tcsh
# mrtrixenv
# foreach sub (mgh_????)
#     echo $sub
#     set input =  $sub/1k/fa.nii.gz
#     set output = $sub/t12fa_n.nii.gz
#     set ref = $sub/t1_bet.nii.gz
# #     mrresize $input -voxel 1,1,1 $sub/fa_res.nii.gz -force
#     flirt -in $sub/fa_res.nii.gz -ref $ref -omat $sub/diff2str_n.mat -dof 6 -cost normmi
#     convert_xfm  -omat $sub/str2diff_n.mat -inverse  $sub/diff2str_n.mat
#     flirt -in $ref -ref $sub/fa_res.nii.gz -out $output -init $sub/str2diff_n.mat -applyxfm
# end
# Out:
# mgh_1001
# mgh_1002
# mgh_1003
# mgh_1004
# mgh_1005
# mgh_1006
# mgh_1007
# mgh_1008
# mgh_1009
# mgh_1010
# mgh_1011
# mgh_1012
# mgh_1013
# mgh_1014
# mgh_1015
# mgh_1016
# mgh_1017
# mgh_1018
# mgh_1019
# mgh_1021
# mgh_1022
# mgh_1023
# mgh_1024
# mgh_1025
# mgh_1026
# mgh_1027
# mgh_1028
# mgh_1029
# mgh_1030
# mgh_1031
# mgh_1032
# mgh_1033
# mgh_1034
# mgh_1035
# stdin: is not a tty

# %%
# %%script tcsh
# mrtrixenv
# foreach sub (mgh_????)
#      fast $sub/t12fa_n.nii.gz
# end
# Out:
# stdin: is not a tty

# %%
# %%script tcsh
# mrtrixenv
# foreach sub (mgh_????)
#     echo $sub
#     mri_convert $sub/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 $sub/t12fa_n_pve_0_res.nii.gz -rt nearest
#     mri_convert $sub/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 $sub/t12fa_n_pve_1_res.nii.gz -rt nearest
#     mri_convert $sub/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 $sub/t12fa_n_pve_2_res.nii.gz -rt nearest
# end
# Out:
# mgh_1001
# mri_convert mgh_1001/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1001/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1001/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.978592, 0.199719, 0.0496895)
# j_ras = (0.199352, 0.859859, 0.470001)
# k_ras = (-0.0511422, -0.469845, 0.881266)
# Reslicing using nearest
# writing to mgh_1001/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1001/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1001/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1001/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.978592, 0.199719, 0.0496895)
# j_ras = (0.199352, 0.859859, 0.470001)
# k_ras = (-0.0511422, -0.469845, 0.881266)
# Reslicing using nearest
# writing to mgh_1001/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1001/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1001/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1001/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.978592, 0.199719, 0.0496895)
# j_ras = (0.199352, 0.859859, 0.470001)
# k_ras = (-0.0511422, -0.469845, 0.881266)
# Reslicing using nearest
# writing to mgh_1001/t12fa_n_pve_2_res.nii.gz...
# mgh_1002
# mri_convert mgh_1002/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1002/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1002/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.995692, 0.0821469, 0.0430038)
# j_ras = (0.0919623, 0.815632, 0.571216)
# k_ras = (-0.0118484, -0.57271, 0.819672)
# Reslicing using nearest
# writing to mgh_1002/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1002/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1002/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1002/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.995692, 0.0821469, 0.0430038)
# j_ras = (0.0919623, 0.815632, 0.571216)
# k_ras = (-0.0118484, -0.57271, 0.819672)
# Reslicing using nearest
# writing to mgh_1002/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1002/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1002/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1002/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.995692, 0.0821469, 0.0430038)
# j_ras = (0.0919623, 0.815632, 0.571216)
# k_ras = (-0.0118484, -0.57271, 0.819672)
# Reslicing using nearest
# writing to mgh_1002/t12fa_n_pve_2_res.nii.gz...
# mgh_1003
# mri_convert mgh_1003/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1003/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1003/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999173, -0.0261526, -0.0311496)
# j_ras = (-0.0388549, 0.840152, 0.540957)
# k_ras = (-0.0120231, -0.541719, 0.840473)
# Reslicing using nearest
# writing to mgh_1003/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1003/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1003/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1003/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999173, -0.0261526, -0.0311496)
# j_ras = (-0.0388549, 0.840152, 0.540957)
# k_ras = (-0.0120231, -0.541719, 0.840473)
# Reslicing using nearest
# writing to mgh_1003/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1003/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1003/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1003/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999173, -0.0261526, -0.0311496)
# j_ras = (-0.0388549, 0.840152, 0.540957)
# k_ras = (-0.0120231, -0.541719, 0.840473)
# Reslicing using nearest
# writing to mgh_1003/t12fa_n_pve_2_res.nii.gz...
# mgh_1004
# mri_convert mgh_1004/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1004/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1004/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998754, 0.0496573, 0.00491164)
# j_ras = (0.0443312, 0.837808, 0.544163)
# k_ras = (-0.0229066, -0.543702, 0.838965)
# Reslicing using nearest
# writing to mgh_1004/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1004/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1004/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1004/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998754, 0.0496573, 0.00491164)
# j_ras = (0.0443312, 0.837808, 0.544163)
# k_ras = (-0.0229066, -0.543702, 0.838965)
# Reslicing using nearest
# writing to mgh_1004/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1004/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1004/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1004/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998754, 0.0496573, 0.00491164)
# j_ras = (0.0443312, 0.837808, 0.544163)
# k_ras = (-0.0229066, -0.543702, 0.838965)
# Reslicing using nearest
# writing to mgh_1004/t12fa_n_pve_2_res.nii.gz...
# mgh_1005
# mri_convert mgh_1005/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1005/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1005/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999006, 0.0366417, -0.0253993)
# j_ras = (0.0205796, 0.884357, 0.466358)
# k_ras = (-0.0395502, -0.465371, 0.884231)
# Reslicing using nearest
# writing to mgh_1005/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1005/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1005/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1005/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999006, 0.0366417, -0.0253993)
# j_ras = (0.0205796, 0.884357, 0.466358)
# k_ras = (-0.0395502, -0.465371, 0.884231)
# Reslicing using nearest
# writing to mgh_1005/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1005/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1005/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1005/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999006, 0.0366417, -0.0253993)
# j_ras = (0.0205796, 0.884357, 0.466358)
# k_ras = (-0.0395502, -0.465371, 0.884231)
# Reslicing using nearest
# writing to mgh_1005/t12fa_n_pve_2_res.nii.gz...
# mgh_1006
# mri_convert mgh_1006/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1006/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1006/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.995867, -0.0205994, 0.088452)
# j_ras = (0.0350726, 0.811151, 0.583784)
# k_ras = (0.0837736, -0.584474, 0.807076)
# Reslicing using nearest
# writing to mgh_1006/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1006/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1006/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1006/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.995867, -0.0205994, 0.088452)
# j_ras = (0.0350726, 0.811151, 0.583784)
# k_ras = (0.0837736, -0.584474, 0.807076)
# Reslicing using nearest
# writing to mgh_1006/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1006/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1006/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1006/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.995867, -0.0205994, 0.088452)
# j_ras = (0.0350726, 0.811151, 0.583784)
# k_ras = (0.0837736, -0.584474, 0.807076)
# Reslicing using nearest
# writing to mgh_1006/t12fa_n_pve_2_res.nii.gz...
# mgh_1007
# mri_convert mgh_1007/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1007/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1007/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.997828, 0.042907, -0.0499772)
# j_ras = (0.00154558, 0.773778, 0.633454)
# k_ras = (-0.0658509, -0.632002, 0.772164)
# Reslicing using nearest
# writing to mgh_1007/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1007/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1007/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1007/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.997828, 0.042907, -0.0499772)
# j_ras = (0.00154558, 0.773778, 0.633454)
# k_ras = (-0.0658509, -0.632002, 0.772164)
# Reslicing using nearest
# writing to mgh_1007/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1007/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1007/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1007/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.997828, 0.042907, -0.0499772)
# j_ras = (0.00154558, 0.773778, 0.633454)
# k_ras = (-0.0658509, -0.632002, 0.772164)
# Reslicing using nearest
# writing to mgh_1007/t12fa_n_pve_2_res.nii.gz...
# mgh_1008
# mri_convert mgh_1008/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1008/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1008/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999119, 0.0177503, 0.0380261)
# j_ras = (0.0379101, 0.770368, 0.636471)
# k_ras = (0.0179965, -0.637352, 0.770363)
# Reslicing using nearest
# writing to mgh_1008/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1008/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1008/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1008/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999119, 0.0177503, 0.0380261)
# j_ras = (0.0379101, 0.770368, 0.636471)
# k_ras = (0.0179965, -0.637352, 0.770363)
# Reslicing using nearest
# writing to mgh_1008/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1008/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1008/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1008/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999119, 0.0177503, 0.0380261)
# j_ras = (0.0379101, 0.770368, 0.636471)
# k_ras = (0.0179965, -0.637352, 0.770363)
# Reslicing using nearest
# writing to mgh_1008/t12fa_n_pve_2_res.nii.gz...
# mgh_1009
# mri_convert mgh_1009/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1009/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1009/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99362, 0.107985, 0.0325488)
# j_ras = (0.112157, 0.91567, 0.385966)
# k_ras = (-0.0118745, -0.387154, 0.921939)
# Reslicing using nearest
# writing to mgh_1009/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1009/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1009/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1009/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99362, 0.107985, 0.0325488)
# j_ras = (0.112157, 0.91567, 0.385966)
# k_ras = (-0.0118745, -0.387154, 0.921939)
# Reslicing using nearest
# writing to mgh_1009/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1009/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1009/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1009/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99362, 0.107985, 0.0325488)
# j_ras = (0.112157, 0.91567, 0.385966)
# k_ras = (-0.0118745, -0.387154, 0.921939)
# Reslicing using nearest
# writing to mgh_1009/t12fa_n_pve_2_res.nii.gz...
# mgh_1010
# mri_convert mgh_1010/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1010/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1010/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999898, -0.00617167, -0.0129013)
# j_ras = (-0.013008, 0.76736, 0.641084)
# k_ras = (-0.00594342, -0.641187, 0.767362)
# Reslicing using nearest
# writing to mgh_1010/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1010/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1010/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1010/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999898, -0.00617167, -0.0129013)
# j_ras = (-0.013008, 0.76736, 0.641084)
# k_ras = (-0.00594342, -0.641187, 0.767362)
# Reslicing using nearest
# writing to mgh_1010/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1010/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1010/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1010/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999898, -0.00617167, -0.0129013)
# j_ras = (-0.013008, 0.76736, 0.641084)
# k_ras = (-0.00594342, -0.641187, 0.767362)
# Reslicing using nearest
# writing to mgh_1010/t12fa_n_pve_2_res.nii.gz...
# mgh_1011
# mri_convert mgh_1011/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1011/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1011/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996967, -0.0269304, 0.0730163)
# j_ras = (0.0224823, 0.798554, 0.601503)
# k_ras = (0.0745062, -0.60132, 0.795527)
# Reslicing using nearest
# writing to mgh_1011/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1011/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1011/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1011/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996967, -0.0269304, 0.0730163)
# j_ras = (0.0224823, 0.798554, 0.601503)
# k_ras = (0.0745062, -0.60132, 0.795527)
# Reslicing using nearest
# writing to mgh_1011/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1011/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1011/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1011/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996967, -0.0269304, 0.0730163)
# j_ras = (0.0224823, 0.798554, 0.601503)
# k_ras = (0.0745062, -0.60132, 0.795527)
# Reslicing using nearest
# writing to mgh_1011/t12fa_n_pve_2_res.nii.gz...
# mgh_1012
# mri_convert mgh_1012/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1012/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1012/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99894, 0.0458938, 0.00357947)
# j_ras = (0.0406205, 0.842231, 0.537584)
# k_ras = (-0.0216571, -0.53716, 0.843202)
# Reslicing using nearest
# writing to mgh_1012/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1012/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1012/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1012/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99894, 0.0458938, 0.00357947)
# j_ras = (0.0406205, 0.842231, 0.537584)
# k_ras = (-0.0216571, -0.53716, 0.843202)
# Reslicing using nearest
# writing to mgh_1012/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1012/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1012/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1012/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99894, 0.0458938, 0.00357947)
# j_ras = (0.0406205, 0.842231, 0.537584)
# k_ras = (-0.0216571, -0.53716, 0.843202)
# Reslicing using nearest
# writing to mgh_1012/t12fa_n_pve_2_res.nii.gz...
# mgh_1013
# mri_convert mgh_1013/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1013/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1013/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998146, 0.0348559, 0.049888)
# j_ras = (0.0576571, 0.803968, 0.591871)
# k_ras = (0.0194781, -0.59365, 0.804488)
# Reslicing using nearest
# writing to mgh_1013/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1013/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1013/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1013/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998146, 0.0348559, 0.049888)
# j_ras = (0.0576571, 0.803968, 0.591871)
# k_ras = (0.0194781, -0.59365, 0.804488)
# Reslicing using nearest
# writing to mgh_1013/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1013/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1013/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1013/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998146, 0.0348559, 0.049888)
# j_ras = (0.0576571, 0.803968, 0.591871)
# k_ras = (0.0194781, -0.59365, 0.804488)
# Reslicing using nearest
# writing to mgh_1013/t12fa_n_pve_2_res.nii.gz...
# mgh_1014
# mri_convert mgh_1014/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1014/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1014/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998198, 0.00842581, 0.059419)
# j_ras = (0.0392488, 0.840656, 0.540146)
# k_ras = (0.0453998, -0.541504, 0.839471)
# Reslicing using nearest
# writing to mgh_1014/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1014/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1014/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1014/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998198, 0.00842581, 0.059419)
# j_ras = (0.0392488, 0.840656, 0.540146)
# k_ras = (0.0453998, -0.541504, 0.839471)
# Reslicing using nearest
# writing to mgh_1014/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1014/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1014/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1014/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998198, 0.00842581, 0.059419)
# j_ras = (0.0392488, 0.840656, 0.540146)
# k_ras = (0.0453998, -0.541504, 0.839471)
# Reslicing using nearest
# writing to mgh_1014/t12fa_n_pve_2_res.nii.gz...
# mgh_1015
# mri_convert mgh_1015/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1015/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1015/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998593, 0.0528764, 0.00397389)
# j_ras = (0.0433223, 0.77035, 0.636148)
# k_ras = (-0.030576, -0.635425, 0.771557)
# Reslicing using nearest
# writing to mgh_1015/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1015/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1015/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1015/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998593, 0.0528764, 0.00397389)
# j_ras = (0.0433223, 0.77035, 0.636148)
# k_ras = (-0.030576, -0.635425, 0.771557)
# Reslicing using nearest
# writing to mgh_1015/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1015/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1015/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1015/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998593, 0.0528764, 0.00397389)
# j_ras = (0.0433223, 0.77035, 0.636148)
# k_ras = (-0.030576, -0.635425, 0.771557)
# Reslicing using nearest
# writing to mgh_1015/t12fa_n_pve_2_res.nii.gz...
# mgh_1016
# mri_convert mgh_1016/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1016/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1016/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999991, -0.000365187, 0.00415473)
# j_ras = (0.00218278, 0.803018, 0.595951)
# k_ras = (0.00355402, -0.595955, 0.80301)
# Reslicing using nearest
# writing to mgh_1016/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1016/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1016/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1016/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999991, -0.000365187, 0.00415473)
# j_ras = (0.00218278, 0.803018, 0.595951)
# k_ras = (0.00355402, -0.595955, 0.80301)
# Reslicing using nearest
# writing to mgh_1016/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1016/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1016/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1016/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999991, -0.000365187, 0.00415473)
# j_ras = (0.00218278, 0.803018, 0.595951)
# k_ras = (0.00355402, -0.595955, 0.80301)
# Reslicing using nearest
# writing to mgh_1016/t12fa_n_pve_2_res.nii.gz...
# mgh_1017
# mri_convert mgh_1017/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1017/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1017/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.992912, 0.0686668, 0.0970111)
# j_ras = (0.113061, 0.797395, 0.592772)
# k_ras = (0.0366526, -0.599538, 0.799507)
# Reslicing using nearest
# writing to mgh_1017/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1017/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1017/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1017/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.992912, 0.0686668, 0.0970111)
# j_ras = (0.113061, 0.797395, 0.592772)
# k_ras = (0.0366526, -0.599538, 0.799507)
# Reslicing using nearest
# writing to mgh_1017/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1017/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1017/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1017/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.992912, 0.0686668, 0.0970111)
# j_ras = (0.113061, 0.797395, 0.592772)
# k_ras = (0.0366526, -0.599538, 0.799507)
# Reslicing using nearest
# writing to mgh_1017/t12fa_n_pve_2_res.nii.gz...
# mgh_1018
# mri_convert mgh_1018/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1018/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1018/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999204, -0.0393738, -0.00648355)
# j_ras = (-0.0350451, 0.788173, 0.614455)
# k_ras = (0.0190833, -0.614193, 0.788925)
# Reslicing using nearest
# writing to mgh_1018/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1018/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1018/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1018/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999204, -0.0393738, -0.00648355)
# j_ras = (-0.0350451, 0.788173, 0.614455)
# k_ras = (0.0190833, -0.614193, 0.788925)
# Reslicing using nearest
# writing to mgh_1018/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1018/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1018/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1018/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999204, -0.0393738, -0.00648355)
# j_ras = (-0.0350451, 0.788173, 0.614455)
# k_ras = (0.0190833, -0.614193, 0.788925)
# Reslicing using nearest
# writing to mgh_1018/t12fa_n_pve_2_res.nii.gz...
# mgh_1019
# mri_convert mgh_1019/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1019/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1019/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996949, -0.0014681, -0.0780373)
# j_ras = (-0.0364624, 0.892776, 0.449022)
# k_ras = (-0.0690106, -0.450498, 0.890106)
# Reslicing using nearest
# writing to mgh_1019/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1019/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1019/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1019/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996949, -0.0014681, -0.0780373)
# j_ras = (-0.0364624, 0.892776, 0.449022)
# k_ras = (-0.0690106, -0.450498, 0.890106)
# Reslicing using nearest
# writing to mgh_1019/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1019/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1019/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1019/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996949, -0.0014681, -0.0780373)
# j_ras = (-0.0364624, 0.892776, 0.449022)
# k_ras = (-0.0690106, -0.450498, 0.890106)
# Reslicing using nearest
# writing to mgh_1019/t12fa_n_pve_2_res.nii.gz...
# mgh_1021
# mri_convert mgh_1021/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1021/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1021/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99911, 0.0308078, 0.0288083)
# j_ras = (0.0402132, 0.90182, 0.430236)
# k_ras = (0.0127252, -0.431012, 0.902256)
# Reslicing using nearest
# writing to mgh_1021/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1021/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1021/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1021/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99911, 0.0308078, 0.0288083)
# j_ras = (0.0402132, 0.90182, 0.430236)
# k_ras = (0.0127252, -0.431012, 0.902256)
# Reslicing using nearest
# writing to mgh_1021/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1021/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1021/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1021/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99911, 0.0308078, 0.0288083)
# j_ras = (0.0402132, 0.90182, 0.430236)
# k_ras = (0.0127252, -0.431012, 0.902256)
# Reslicing using nearest
# writing to mgh_1021/t12fa_n_pve_2_res.nii.gz...
# mgh_1022
# mri_convert mgh_1022/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1022/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1022/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999536, 0.0265164, 0.014962)
# j_ras = (0.0304394, 0.859733, 0.509836)
# k_ras = (-0.00065565, -0.510055, 0.860142)
# Reslicing using nearest
# writing to mgh_1022/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1022/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1022/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1022/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999536, 0.0265164, 0.014962)
# j_ras = (0.0304394, 0.859733, 0.509836)
# k_ras = (-0.00065565, -0.510055, 0.860142)
# Reslicing using nearest
# writing to mgh_1022/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1022/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1022/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1022/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999536, 0.0265164, 0.014962)
# j_ras = (0.0304394, 0.859733, 0.509836)
# k_ras = (-0.00065565, -0.510055, 0.860142)
# Reslicing using nearest
# writing to mgh_1022/t12fa_n_pve_2_res.nii.gz...
# mgh_1023
# mri_convert mgh_1023/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1023/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1023/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996585, 0.0121683, -0.0816725)
# j_ras = (-0.0296715, 0.87025, 0.491715)
# k_ras = (-0.0770589, -0.492459, 0.866917)
# Reslicing using nearest
# writing to mgh_1023/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1023/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1023/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1023/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996585, 0.0121683, -0.0816725)
# j_ras = (-0.0296715, 0.87025, 0.491715)
# k_ras = (-0.0770589, -0.492459, 0.866917)
# Reslicing using nearest
# writing to mgh_1023/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1023/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1023/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1023/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996585, 0.0121683, -0.0816725)
# j_ras = (-0.0296715, 0.87025, 0.491715)
# k_ras = (-0.0770589, -0.492459, 0.866917)
# Reslicing using nearest
# writing to mgh_1023/t12fa_n_pve_2_res.nii.gz...
# mgh_1024
# mri_convert mgh_1024/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1024/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1024/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998122, -0.0382012, 0.0478907)
# j_ras = (-0.0170313, 0.923976, 0.38207)
# k_ras = (0.0588454, -0.380537, 0.922891)
# Reslicing using nearest
# writing to mgh_1024/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1024/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1024/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1024/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998122, -0.0382012, 0.0478907)
# j_ras = (-0.0170313, 0.923976, 0.38207)
# k_ras = (0.0588454, -0.380537, 0.922891)
# Reslicing using nearest
# writing to mgh_1024/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1024/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1024/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1024/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998122, -0.0382012, 0.0478907)
# j_ras = (-0.0170313, 0.923976, 0.38207)
# k_ras = (0.0588454, -0.380537, 0.922891)
# Reslicing using nearest
# writing to mgh_1024/t12fa_n_pve_2_res.nii.gz...
# mgh_1025
# mri_convert mgh_1025/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1025/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1025/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999133, -0.0194033, 0.036824)
# j_ras = (0.00519124, 0.8197, 0.572769)
# k_ras = (0.0412984, -0.572464, 0.818889)
# Reslicing using nearest
# writing to mgh_1025/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1025/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1025/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1025/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999133, -0.0194033, 0.036824)
# j_ras = (0.00519124, 0.8197, 0.572769)
# k_ras = (0.0412984, -0.572464, 0.818889)
# Reslicing using nearest
# writing to mgh_1025/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1025/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1025/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1025/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999133, -0.0194033, 0.036824)
# j_ras = (0.00519124, 0.8197, 0.572769)
# k_ras = (0.0412984, -0.572464, 0.818889)
# Reslicing using nearest
# writing to mgh_1025/t12fa_n_pve_2_res.nii.gz...
# mgh_1026
# mri_convert mgh_1026/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1026/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1026/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998106, -0.061511, 4.64685e-05)
# j_ras = (-0.0525097, 0.85244, 0.520181)
# k_ras = (0.0320363, -0.519194, 0.854056)
# Reslicing using nearest
# writing to mgh_1026/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1026/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1026/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1026/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998106, -0.061511, 4.64685e-05)
# j_ras = (-0.0525097, 0.85244, 0.520181)
# k_ras = (0.0320363, -0.519194, 0.854056)
# Reslicing using nearest
# writing to mgh_1026/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1026/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1026/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1026/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.998106, -0.061511, 4.64685e-05)
# j_ras = (-0.0525097, 0.85244, 0.520181)
# k_ras = (0.0320363, -0.519194, 0.854056)
# Reslicing using nearest
# writing to mgh_1026/t12fa_n_pve_2_res.nii.gz...
# mgh_1027
# mri_convert mgh_1027/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1027/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1027/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.997393, 0.0612617, -0.0381336)
# j_ras = (0.0366954, 0.885616, 0.462967)
# k_ras = (-0.0621339, -0.460361, 0.885555)
# Reslicing using nearest
# writing to mgh_1027/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1027/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1027/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1027/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.997393, 0.0612617, -0.0381336)
# j_ras = (0.0366954, 0.885616, 0.462967)
# k_ras = (-0.0621339, -0.460361, 0.885555)
# Reslicing using nearest
# writing to mgh_1027/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1027/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1027/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1027/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.997393, 0.0612617, -0.0381336)
# j_ras = (0.0366954, 0.885616, 0.462967)
# k_ras = (-0.0621339, -0.460361, 0.885555)
# Reslicing using nearest
# writing to mgh_1027/t12fa_n_pve_2_res.nii.gz...
# mgh_1028
# mri_convert mgh_1028/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1028/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1028/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999519, 0.0308008, -0.00351083)
# j_ras = (0.0211786, 0.761156, 0.648224)
# k_ras = (-0.0226381, -0.647838, 0.761442)
# Reslicing using nearest
# writing to mgh_1028/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1028/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1028/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1028/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999519, 0.0308008, -0.00351083)
# j_ras = (0.0211786, 0.761156, 0.648224)
# k_ras = (-0.0226381, -0.647838, 0.761442)
# Reslicing using nearest
# writing to mgh_1028/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1028/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1028/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1028/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999519, 0.0308008, -0.00351083)
# j_ras = (0.0211786, 0.761156, 0.648224)
# k_ras = (-0.0226381, -0.647838, 0.761442)
# Reslicing using nearest
# writing to mgh_1028/t12fa_n_pve_2_res.nii.gz...
# mgh_1029
# mri_convert mgh_1029/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1029/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1029/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999979, 0.00605852, -0.00246487)
# j_ras = (0.00412009, 0.876145, 0.48203)
# k_ras = (-0.00507989, -0.48201, 0.876151)
# Reslicing using nearest
# writing to mgh_1029/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1029/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1029/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1029/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999979, 0.00605852, -0.00246487)
# j_ras = (0.00412009, 0.876145, 0.48203)
# k_ras = (-0.00507989, -0.48201, 0.876151)
# Reslicing using nearest
# writing to mgh_1029/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1029/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1029/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1029/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999979, 0.00605852, -0.00246487)
# j_ras = (0.00412009, 0.876145, 0.48203)
# k_ras = (-0.00507989, -0.48201, 0.876151)
# Reslicing using nearest
# writing to mgh_1029/t12fa_n_pve_2_res.nii.gz...
# mgh_1030
# mri_convert mgh_1030/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1030/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1030/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999117, 0.038024, -0.0178868)
# j_ras = (0.0190074, 0.788573, 0.614648)
# k_ras = (-0.0374765, -0.613765, 0.788599)
# Reslicing using nearest
# writing to mgh_1030/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1030/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1030/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1030/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999117, 0.038024, -0.0178868)
# j_ras = (0.0190074, 0.788573, 0.614648)
# k_ras = (-0.0374765, -0.613765, 0.788599)
# Reslicing using nearest
# writing to mgh_1030/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1030/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1030/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1030/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999117, 0.038024, -0.0178868)
# j_ras = (0.0190074, 0.788573, 0.614648)
# k_ras = (-0.0374765, -0.613765, 0.788599)
# Reslicing using nearest
# writing to mgh_1030/t12fa_n_pve_2_res.nii.gz...
# mgh_1031
# mri_convert mgh_1031/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1031/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1031/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999383, 0.0235906, -0.0260206)
# j_ras = (0.00339396, 0.80225, 0.596979)
# k_ras = (-0.0349581, -0.596522, 0.801835)
# Reslicing using nearest
# writing to mgh_1031/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1031/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1031/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1031/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999383, 0.0235906, -0.0260206)
# j_ras = (0.00339396, 0.80225, 0.596979)
# k_ras = (-0.0349581, -0.596522, 0.801835)
# Reslicing using nearest
# writing to mgh_1031/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1031/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1031/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1031/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.999383, 0.0235906, -0.0260206)
# j_ras = (0.00339396, 0.80225, 0.596979)
# k_ras = (-0.0349581, -0.596522, 0.801835)
# Reslicing using nearest
# writing to mgh_1031/t12fa_n_pve_2_res.nii.gz...
# mgh_1032
# mri_convert mgh_1032/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1032/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1032/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99716, 0.0380429, 0.0650046)
# j_ras = (0.0633688, 0.890236, 0.451071)
# k_ras = (0.0407094, -0.453909, 0.890118)
# Reslicing using nearest
# writing to mgh_1032/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1032/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1032/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1032/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99716, 0.0380429, 0.0650046)
# j_ras = (0.0633688, 0.890236, 0.451071)
# k_ras = (0.0407094, -0.453909, 0.890118)
# Reslicing using nearest
# writing to mgh_1032/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1032/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1032/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1032/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99716, 0.0380429, 0.0650046)
# j_ras = (0.0633688, 0.890236, 0.451071)
# k_ras = (0.0407094, -0.453909, 0.890118)
# Reslicing using nearest
# writing to mgh_1032/t12fa_n_pve_2_res.nii.gz...
# mgh_1033
# mri_convert mgh_1033/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1033/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1033/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99954, 0.0303226, -0.000351328)
# j_ras = (0.0257764, 0.855668, 0.516883)
# k_ras = (-0.0159737, -0.516636, 0.856056)
# Reslicing using nearest
# writing to mgh_1033/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1033/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1033/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1033/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99954, 0.0303226, -0.000351328)
# j_ras = (0.0257764, 0.855668, 0.516883)
# k_ras = (-0.0159737, -0.516636, 0.856056)
# Reslicing using nearest
# writing to mgh_1033/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1033/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1033/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1033/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.99954, 0.0303226, -0.000351328)
# j_ras = (0.0257764, 0.855668, 0.516883)
# k_ras = (-0.0159737, -0.516636, 0.856056)
# Reslicing using nearest
# writing to mgh_1033/t12fa_n_pve_2_res.nii.gz...
# mgh_1034
# mri_convert mgh_1034/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1034/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1034/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996604, 0.0514443, 0.0642931)
# j_ras = (0.0781651, 0.836578, 0.542242)
# k_ras = (0.0258908, -0.545426, 0.837759)
# Reslicing using nearest
# writing to mgh_1034/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1034/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1034/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1034/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996604, 0.0514443, 0.0642931)
# j_ras = (0.0781651, 0.836578, 0.542242)
# k_ras = (0.0258908, -0.545426, 0.837759)
# Reslicing using nearest
# writing to mgh_1034/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1034/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1034/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1034/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996604, 0.0514443, 0.0642931)
# j_ras = (0.0781651, 0.836578, 0.542242)
# k_ras = (0.0258908, -0.545426, 0.837759)
# Reslicing using nearest
# writing to mgh_1034/t12fa_n_pve_2_res.nii.gz...
# mgh_1035
# mri_convert mgh_1035/t12fa_n_pve_0.nii.gz -vs 1.5 1.5 1.5 mgh_1035/t12fa_n_pve_0_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1035/t12fa_n_pve_0.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996924, -0.0369184, 0.069141)
# j_ras = (-0.00223343, 0.895146, 0.445768)
# k_ras = (0.0783484, -0.444242, 0.892474)
# Reslicing using nearest
# writing to mgh_1035/t12fa_n_pve_0_res.nii.gz...
# mri_convert mgh_1035/t12fa_n_pve_1.nii.gz -vs 1.5 1.5 1.5 mgh_1035/t12fa_n_pve_1_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1035/t12fa_n_pve_1.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996924, -0.0369184, 0.069141)
# j_ras = (-0.00223343, 0.895146, 0.445768)
# k_ras = (0.0783484, -0.444242, 0.892474)
# Reslicing using nearest
# writing to mgh_1035/t12fa_n_pve_1_res.nii.gz...
# mri_convert mgh_1035/t12fa_n_pve_2.nii.gz -vs 1.5 1.5 1.5 mgh_1035/t12fa_n_pve_2_res.nii.gz -rt nearest
# $Id: mri_convert.c,v 1.227 2017/02/16 19:15:42 greve Exp $
# reading from mgh_1035/t12fa_n_pve_2.nii.gz...
# TR=1000.00, TE=0.00, TI=0.00, flip angle=0.00
# i_ras = (-0.996924, -0.0369184, 0.069141)
# j_ras = (-0.00223343, 0.895146, 0.445768)
# k_ras = (0.0783484, -0.444242, 0.892474)
# Reslicing using nearest
# writing to mgh_1035/t12fa_n_pve_2_res.nii.gz...
# stdin: is not a tty
